# %%
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array,load_img
import matplotlib.pyplot as plt

# %%
trainPath = 'dataset/train/'
valPath = 'dataset/val/'
testPath = 'dataset/test/'

# %%
shape = (100,128)

# %%
trainDatagen = ImageDataGenerator(
    rescale=1./255,
    width_shift_range=0.2,
    height_shift_range=0.1,
    horizontal_flip = True,
    zoom_range=0.16,
)
trainGenerator = trainDatagen.flow_from_directory(
    trainPath,
    target_size=shape,
    class_mode = 'categorical',
    batch_size=32
)
valDatagen = ImageDataGenerator(
    rescale=1./255
)
valGenerator = valDatagen.flow_from_directory(
    valPath,
    target_size=shape,
    class_mode = 'categorical',
    batch_size=32
)
# Out:
# Found 7939 images belonging to 4 classes.
# Found 1719 images belonging to 4 classes.

# %%
(x,y) = trainGenerator.next()

# %%
index = 16
print(y[index])
plt.imshow(x[index])
# Out:
# [0. 0. 0. 1.]

# %%
import os
load_img(trainPath + 'bee/' + os.listdir(trainPath + 'bee')[6]).size
# Out:
# (320, 240)

# %%
model = keras.models.Sequential([
    layers.Conv2D(filters=64,kernel_size=(3,3),activation='relu',input_shape=list(shape)+[3],kernel_regularizer=keras.regularizers.L2(0.05)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=86,kernel_size=(3,3),activation='relu',kernel_regularizer=keras.regularizers.L2(0.08)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=98,kernel_size=(3,3),activation='relu',kernel_regularizer=keras.regularizers.L2(0.08)),
    layers.BatchNormalization(),
    layers.Flatten(),
    layers.Dense(10,activation='relu',kernel_regularizer=keras.regularizers.L2(0.001)),
    layers.Dense(4,activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_36 (Conv2D)           (None, 98, 126, 64)       1792
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 98, 126, 64)       256
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 49, 63, 64)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 47, 61, 86)        49622
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 47, 61, 86)        344
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 23, 30, 86)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 21, 28, 98)        75950
# ...

# %%
opt = keras.optimizers.Adam()
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['acc'])

# %%
scheduler = lambda epoch: 1e-7 * 10**(epoch/20)
lr_scheduler = keras.callbacks.LearningRateScheduler(scheduler)

# %%
history = model.fit(trainGenerator,validation_data = valGenerator,epochs=40,initial_epoch=0)
# Out:
# Epoch 1/40
# 249/249 [==============================] - 117s 468ms/step - loss: 7.9635 - acc: 0.4700 - val_loss: 8.8547 - val_acc: 0.4363
# Epoch 2/40
# 249/249 [==============================] - 33s 134ms/step - loss: 2.5075 - acc: 0.4718 - val_loss: 2.1394 - val_acc: 0.5067
# Epoch 3/40
# 249/249 [==============================] - 34s 135ms/step - loss: 1.7090 - acc: 0.4877 - val_loss: 1.4863 - val_acc: 0.4985
# Epoch 4/40
# 249/249 [==============================] - 34s 135ms/step - loss: 1.5472 - acc: 0.4721 - val_loss: 1.4598 - val_acc: 0.5003
# Epoch 5/40
# 249/249 [==============================] - 34s 137ms/step - loss: 1.4140 - acc: 0.4857 - val_loss: 1.4277 - val_acc: 0.4863
# Epoch 6/40
# 249/249 [==============================] - 34s 136ms/step - loss: 1.5535 - acc: 0.4453 - val_loss: 1.3444 - val_acc: 0.4363
# Epoch 7/40
# 249/249 [==============================] - 35s 139ms/step - loss: 1.5297 - acc: 0.4333 - val_loss: 1.4660 - val_acc: 0.4363
# Epoch 8/40
# ...

# %%
trainAcc = history.history['acc']
trainLoss = history.history['loss']
valAcc = history.history['val_acc']
valLoss = history.history['val_loss']
epochs = np.arange(1, len(trainAcc)+1)

plt.subplot(1,2,1)
plt.plot(epochs,trainAcc)
plt.plot(epochs,valAcc)
plt.subplot(1,2,2)
plt.plot(epochs,trainLoss)
plt.plot(epochs,valLoss)

# %%
opt = keras.optimizers.Adam(lr=8e-6)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['acc'])

# %%
history1 = model.fit(trainGenerator,validation_data = valGenerator,epochs=270,initial_epoch=230)
# Out:
# Epoch 231/270
# 249/249 [==============================] - 34s 136ms/step - loss: 0.6428 - acc: 0.7865 - val_loss: 0.6741 - val_acc: 0.7935
# Epoch 232/270
# 249/249 [==============================] - 34s 136ms/step - loss: 0.6432 - acc: 0.7866 - val_loss: 0.6715 - val_acc: 0.7941
# Epoch 233/270
# 249/249 [==============================] - 34s 135ms/step - loss: 0.6362 - acc: 0.7918 - val_loss: 0.6823 - val_acc: 0.7882
# Epoch 234/270
# 249/249 [==============================] - 34s 135ms/step - loss: 0.6456 - acc: 0.7855 - val_loss: 0.6675 - val_acc: 0.7935
# Epoch 235/270
# 249/249 [==============================] - 34s 135ms/step - loss: 0.6484 - acc: 0.7836 - val_loss: 0.6706 - val_acc: 0.7929
# Epoch 236/270
# 249/249 [==============================] - 33s 134ms/step - loss: 0.6429 - acc: 0.7841 - val_loss: 0.6832 - val_acc: 0.7906
# Epoch 237/270
# 249/249 [==============================] - 34s 136ms/step - loss: 0.6430 - acc: 0.7890 - val_loss: 0.6666 - val_acc: 0.7976
# ...

# %%
history1.history
# Out:
# {'loss': [0.9854750037193298,
#   0.9759438037872314,
#   0.9800954461097717,
#   0.9806943535804749,
#   0.9927568435668945,
#   0.97886061668396,
#   0.9696118831634521,
#   0.9687306880950928,
#   0.9725106358528137,
#   0.9636610746383667,
#   0.9675168991088867,
#   0.9564741849899292,
#   0.9451067447662354,
#   0.949971079826355,
#   0.936649739742279,
#   0.9242230653762817,
#   0.8966935873031616,
#   0.897990345954895,
#   0.8881794214248657,
#   0.8823971152305603,
#   0.8694804906845093,
#   0.8686020970344543,
#   0.8609428405761719,
#   0.8505101203918457,
#   0.8556610345840454,
#   0.8475591540336609,
#   0.8435980677604675,
#   0.8426999449729919,
#   0.8326559066772461,
#   0.8365857005119324,
#   0.8371334671974182,
#   0.8306620717048645,
#   0.831299364566803,
#   0.8227985501289368,
#   0.8177724480628967,
#   0.8132261037826538,
#   0.8112298846244812,
#   0.8173216581344604,
#   0.8221815228462219,
#   0.8089330792427063,
#   0.8113201260566711,
# ...

# %%
len(history1.history['acc'])
# Out:
# 9

# %%
trainAcc += history1.history['acc']
trainLoss += history1.history['loss']
valAcc += history1.history['val_acc']
valLoss += history1.history['val_loss']
epochs = list(range(1,len(trainAcc)+1))
plt.subplot(1,2,1)
plt.plot(epochs,trainAcc)
plt.plot(epochs,valAcc)
plt.subplot(1,2,2)
plt.plot(epochs,trainLoss)
plt.plot(epochs,valLoss)

# %%
history.history
# Out:
# {'loss': [0.8358631134033203,
#   0.8292944431304932,
#   0.8297692537307739,
#   0.8337487578392029,
#   0.8343818783760071,
#   0.8372955918312073,
#   0.8362519145011902,
#   0.8358062505722046,
#   0.8444154858589172,
#   0.8370720148086548,
#   0.835788905620575,
#   0.829856812953949,
#   0.8334195613861084,
#   0.8305748105049133,
#   0.8400604128837585,
#   0.8300000429153442,
#   0.8326634168624878,
#   0.8373546600341797,
#   0.8328375220298767,
#   0.8329227566719055,
#   0.8333552479743958,
#   0.8296792507171631,
#   0.8268879055976868,
#   0.8216447830200195,
#   0.8236618041992188,
#   0.8207530975341797,
#   0.8209956288337708,
#   0.8259626626968384,
#   0.8223466873168945,
#   0.8203181624412537,
#   0.8192870616912842,
#   0.8196993470191956,
#   0.818605899810791,
#   0.8182726502418518,
#   0.8213985562324524,
#   0.8107901215553284,
#   0.8201329708099365,
#   0.8142101764678955,
#   0.8166906237602234,
#   0.815323531627655],
#  'acc': [0.6645673513412476,
# ...

# %%
import h5py
def loadModel(modelPath):
    json_file = open(modelPath,'r')
    loaded_model_json = json_file.read()
    json_file.close()
    loaded_model = model_from_json(loaded_model_json)
    return loaded_model
# Use loaded_model.load_weights("pathToWeightsFile.h5")

def saveModel(model,savePath):
    model_json = model.to_json()
    with open(savePath,'w') as f:
        f.write(model_json)
# To save weights use model.save_weights("model.h5")

# %%
saveModel(model,"beeWaspCNN.json")

# %%
model.save_weights("model.h5")

# %%
trainLoss = history.history['loss']
lrs = history.history['lr']
plt.semilogx(lrs,trainLoss)
plt.semilogx(lrs,valLoss)
#plt.axis([1e-8,1e-6,0.77,0.85])

# %%
lrs
# Out:
# [1.1220184543019634e-08,
#  1.2589254117941673e-08,
#  1.4125375446227544e-08,
#  1.5848931924611136e-08,
#  1.7782794100389228e-08,
#  1.9952623149688796e-08,
#  2.2387211385683395e-08,
#  2.51188643150958e-08,
#  2.8183829312644537e-08,
#  3.16227766016838e-08,
#  3.548133892335755e-08,
#  3.981071705534972e-08,
#  4.466835921509632e-08,
#  5.011872336272722e-08,
#  5.623413251903491e-08,
#  6.309573444801934e-08,
#  7.079457843841378e-08,
#  7.943282347242815e-08,
#  8.912509381337454e-08,
#  1e-07,
#  1.1220184543019637e-07,
#  1.2589254117941675e-07,
#  1.4125375446227541e-07,
#  1.5848931924611133e-07,
#  1.778279410038923e-07,
#  1.9952623149688798e-07,
#  2.23872113856834e-07,
#  2.5118864315095796e-07,
#  2.8183829312644533e-07,
#  3.162277660168379e-07,
#  3.5481338923357547e-07,
#  3.9810717055349735e-07,
#  4.46683592150963e-07,
#  5.011872336272723e-07,
#  5.623413251903491e-07,
#  6.309573444801933e-07,
#  7.079457843841381e-07,
#  7.943282347242815e-07,
# ...
